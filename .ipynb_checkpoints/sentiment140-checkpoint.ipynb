# %%
from pymongo import MongoClient
from urllib.request import urlopen
import json

# %%
def sentiment_analyize(tweets):
    payload = {"data": [],"language": "en"}
    
    for tweet in tweets:
        payload["data"].append({"text": tweet["text"],"id": tweet["id"]})
    
    payload = json.dumps(payload).encode('utf-8')
    response = urlopen('http://www.sentiment140.com/api/bulkClassifyJson?appid=ccha97u@gmail.com', payload) # request to server
    results = response.read().decode('utf-8') # get the response
    results = json.loads(results)['data']
    for i,result in enumerate(results):
       
        if result['polarity'] == 0:
            tweets[i]["polarity"] = "negative"
        elif result['polarity'] == 2:
            tweets[i]["polarity"] = "neutral"
        elif result['polarity'] == 4:
            tweets[i]["polarity"] = "positive"
        else:
             tweets[i]["polarity"] = "unknown"
    return tweets

        

def scan_db(collectionName,dbName='idea', bulk_size=4000):
    collection = MongoClient('localhost',27017)[dbName][collectionName]
    buffer = []
    sentiment_tweets = []
    for tweet in collection.find().limit(10):
        buffer.append(tweet)
        if len(buffer) >= bulk_size:
            sentiment_tweets += sentiment_analyize(buffer)
            buffer = []
    
    
    sentiment_tweets += sentiment_analyize(buffer)
    
    return sentiment_tweets

# %%
x = json.loads(page)

# %%
x['data']
# Out:
# [{'meta': {'language': 'en'}, 'polarity': 4, 'text': 'I love Titanic.'},
#  {'meta': {'language': 'en'}, 'polarity': 0, 'text': 'I hate Titanic.'}]

# %%
tweets = scan_db("BPD_581")

# %%
len(tweets[0]
# Out:
# [{'_id': ObjectId('55c612f39c78aa21398b74c0'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2015, 6, 7, 8, 25, 59),
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 62513246,
#      'id_str': '62513246',
#      'indices': [0, 11],
#      'name': 'J.K. Rowling',
#      'screen_name': 'jk_rowling'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 607463499694903297,
#   'id_str': '607463499694903297',
#   'in_reply_to_screen_name': 'jk_rowling',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 62513246,
#   'in_reply_to_user_id_str': '62513246',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'neutral',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@jk_rowling I just want you to know that you are my hero and a pure genius, your books have literally saved my life!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 11 22:40:04 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Birth Mom with Borderline Personality Disorder that happens to be a foodie who is totally obsessed with Harry Potter 3',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3,
#    'follow_request_sent': False,
#    'followers_count': 20,
#    'following': False,
#    'friends_count': 221,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3192520824,
#    'id_str': '3192520824',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'California, USA',
#    'name': 'Courtney Lynn',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3192520824/1433666626',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/607467978305634304/VtaECIMw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/607467978305634304/VtaECIMw_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BelleLuvgood',
#    'statuses_count': 4,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c4'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2014, 11, 6, 20, 9, 34),
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 530451946516545536,
#   'id_str': '530451946516545536',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'neutral',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>',
#   'text': 'I need some sleeping pills. Asap',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c1'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2015, 5, 14, 18, 49, 3),
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'playbuzz.com/toddbriscoelit…',
#      'expanded_url': 'http://www.playbuzz.com/toddbriscoelittlethings10/what-dog-breed-are-you',
#      'indices': [42, 64],
#      'url': 'http://t.co/EGEgjs1WCD'}],
#    'user_mentions': [{'id': 1698876667,
#      'id_str': '1698876667',
#      'indices': [69, 79],
#      'name': 'Playbuzz',
#      'screen_name': 'play_buzz'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 598922992727396352,
#   'id_str': '598922992727396352',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'neutral',
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://mobile.twitter.com" rel="nofollow">Mobile Web</a>',
#   'text': 'I got: Chihuahua! What Dog Breed Are You? http://t.co/EGEgjs1WCD via @play_buzz',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 11 22:40:04 +0000 2015',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Birth Mom with Borderline Personality Disorder that happens to be a foodie who is totally obsessed with Harry Potter 3',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 3,
#    'follow_request_sent': False,
#    'followers_count': 20,
#    'following': False,
#    'friends_count': 221,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 3192520824,
#    'id_str': '3192520824',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': 'California, USA',
#    'name': 'Courtney Lynn',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3192520824/1433666626',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/607467978305634304/VtaECIMw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/607467978305634304/VtaECIMw_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'BelleLuvgood',
#    'statuses_count': 4,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c2'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2015, 6, 4, 5, 3, 22),
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 55876748,
#      'id_str': '55876748',
#      'indices': [0, 13],
#      'name': 'Alex Grey',
#      'screen_name': 'alexgreycosm'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 606325345734828032,
#   'id_str': '606325345734828032',
#   'in_reply_to_screen_name': 'alexgreycosm',
#   'in_reply_to_status_id': 606310890074312706,
#   'in_reply_to_status_id_str': '606310890074312706',
#   'in_reply_to_user_id': 55876748,
#   'in_reply_to_user_id_str': '55876748',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'positive',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@alexgreycosm loooove it, ive seen this too, on pot',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c3'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2015, 3, 16, 17, 7, 24),
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'm.thespec.com/opinion-story/…',
#      'expanded_url': 'http://m.thespec.com/opinion-story/5478592-why-i-intend-to-wear-a-niqab-at-my-citizenship-ceremony/',
#      'indices': [118, 140],
#      'url': 'http://t.co/NOiFccZ7Y2'}],
#    'user_mentions': [{'id': 429227921,
#      'id_str': '429227921',
#      'indices': [0, 10],
#      'name': 'Cenk Uygur',
#      'screen_name': 'cenkuygur'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 577516525831192576,
#   'id_str': '577516525831192576',
#   'in_reply_to_screen_name': 'cenkuygur',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 429227921,
#   'in_reply_to_user_id_str': '429227921',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'neutral',
#   'possibly_sensitive': False,
#   'retweet_count': 1,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '@cenkuygur U NEED to read this If u ever want to have peace u need 2 check ur bias Cenk clearly its not opressing her http://t.co/NOiFccZ7Y2',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c5'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2014, 10, 7, 23, 47, 5),
#   'entities': {'hashtags': [{'indices': [72, 80], 'text': 'tytlive'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 519635053328859137,
#   'id_str': '519635053328859137',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'negative',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>',
#   'text': '... Idc what he did he has the right to get help even tho he hurt me... #tytlive',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c6'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2014, 10, 7, 23, 46, 30),
#   'entities': {'hashtags': [{'indices': [136, 144], 'text': 'tytlive'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 519634905458692097,
#   'id_str': '519634905458692097',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'negative',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>',
#   'text': "As a victim of sex-abuse and I am so grateful he went to therapy so it doesn't happen again. &amp;I'd never wish that being released... #tytlive",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c7'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2014, 10, 4, 5, 20, 34),
#   'entities': {'hashtags': [{'indices': [102, 114], 'text': 'BPDproblems'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 518269426760945664,
#   'id_str': '518269426760945664',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'negative',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>',
#   'text': 'Feeling like everything is ur fault when someone is mad, not even at you, just in ur presence and mad #BPDproblems',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c8'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2014, 9, 27, 16, 45, 21),
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 251034792,
#      'id_str': '251034792',
#      'indices': [0, 10],
#      'name': 'Al Caselli HW',
#      'screen_name': 'AlCaselli'}]},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 515905040884981760,
#   'id_str': '515905040884981760',
#   'in_reply_to_screen_name': 'AlCaselli',
#   'in_reply_to_status_id': 515904829022289920,
#   'in_reply_to_status_id_str': '515904829022289920',
#   'in_reply_to_user_id': 251034792,
#   'in_reply_to_user_id_str': '251034792',
#   'is_quote_status': False,
#   'lang': 'und',
#   'place': None,
#   'polarity': 'neutral',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>',
#   'text': '@AlCaselli tv ^_^',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'_id': ObjectId('55c612f39c78aa21398b74c9'),
#   'contributors': None,
#   'coordinates': None,
#   'created_at': datetime.datetime(2014, 9, 27, 16, 43, 53),
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 251034792,
#      'id_str': '251034792',
#      'indices': [0, 10],
#      'name': 'Al Caselli HW',
#      'screen_name': 'AlCaselli'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 515904671668785152,
#   'id_str': '515904671668785152',
#   'in_reply_to_screen_name': 'AlCaselli',
#   'in_reply_to_status_id': 515904220235841536,
#   'in_reply_to_status_id_str': '515904220235841536',
#   'in_reply_to_user_id': 251034792,
#   'in_reply_to_user_id_str': '251034792',
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'polarity': 'neutral',
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://blackberry.com/twitter" rel="nofollow">Twitter for BlackBerry®</a>',
#   'text': '@AlCaselli ur dog awaits :P',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jun 03 07:58:02 +0000 2012',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': "I have bpd and I am just trying to learn how to deal .. I've started doing poetry to recover from my abuse and to deal with the bpd :).",
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 8,
#    'following': False,
#    'friends_count': 10,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 598213371,
#    'id_str': '598213371',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 0,
#    'location': '',
#    'name': 'nOra ',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme16/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2288274863/jvwv5a6qpqlrgeuxp3ss_normal.jpeg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'LightForUnloved',
#    'statuses_count': 532,
#    'time_zone': None,
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]
